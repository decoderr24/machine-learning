# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2025-03-23 07:35:44--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M  91.2MB/s    in 0.9s
#
# 2025-03-23 07:35:45 (91.2 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
! conda install -c rdkit rdkit -y
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     bottleneck-1.3.4           |   py37hce1f21e_0         126 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2025.2.25  |       h06a4308_0         129 KB
#     cairo-1.14.12              |       h8948797_3         906 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     conda-23.1.0               |   py37h06a4308_0         937 KB
#     flit-core-3.6.0            |     pyhd3eb1b0_0          42 KB
# ...

# %%
# Instalasi RDKit dari conda-forge channel
# !conda install -c conda-forge rdkit -y
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 25.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.3.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.1.31  |       hbcca054_0         154 KB  conda-forge
#     certifi-2024.2.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         311 KB
#
# The following packages will be UPDATED:
#
# ...

# %%
# Gunakan versi pip dengan dependensi yang sesuai
# !pip install rdkit-pypi
# Out:
# ...
#      |████████████████████████████████| 29.2 MB 64.8 MB/s
# ...

# %%
# 1. Install Miniconda
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# 2. Tambahkan conda ke PATH
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# 3. Install RDKit di lingkungan conda
# !conda install -y -q -c conda-forge rdkit numpy=1.21

# 4. Cek versi numpy dan RDKit
import numpy as np
print("NumPy Version:", np.__version__)

from rdkit import Chem
mol = Chem.MolFromSmiles('CCO')
print("RDKit Molecule:", mol)
# Out:
# --2025-03-23 07:47:23--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 154615621 (147M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 147.45M   152MB/s    in 1.0s
#
# 2025-03-23 07:47:24 (152 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [154615621/154615621]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
from rdkit.Chem import Draw

mol = Chem.MolFromSmiles('CCO')
Draw.MolToImage(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit.Chem import Descriptors

mol = Chem.MolFromSmiles('CCO')

print("Molecular Weight:", Descriptors.MolWt(mol))
print("LogP:", Descriptors.MolLogP(mol))
print("Number of H Donors:", Descriptors.NumHDonors(mol))
print("Number of H Acceptors:", Descriptors.NumHAcceptors(mol))
# Out:
# Molecular Weight: 46.069
# LogP: -0.0014000000000000123
# Number of H Donors: 1
# Number of H Acceptors: 1

# %%
from rdkit.Chem import PandasTools
import pandas as pd

smiles_list = ['CCO', 'CCN', 'CCC', 'CCCl']
names = ['Ethanol', 'Ethylamine', 'Propane', 'Chloroethane']

df = pd.DataFrame({'SMILES': smiles_list, 'Name': names})
PandasTools.AddMoleculeColumnToFrame(df, smilesCol='SMILES')
df
# Out:
# Failed to patch pandas - unable to change molecule rendering
#   SMILES          Name                                             ROMol
# 0    CCO       Ethanol  <rdkit.Chem.rdchem.Mol object at 0x79e65be922d0>
# 1    CCN    Ethylamine  <rdkit.Chem.rdchem.Mol object at 0x79e65be90970>
# 2    CCC       Propane  <rdkit.Chem.rdchem.Mol object at 0x79e65be92420>
# 3   CCCl  Chloroethane  <rdkit.Chem.rdchem.Mol object at 0x79e65be92490>
